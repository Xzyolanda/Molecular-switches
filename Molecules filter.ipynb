# %%
from rdkit import Chem
from rdkit.Chem import PandasTools
import pandas as pd
import numpy as np
import time
from rdkit.Chem.Draw import IPythonConsole #Needed to show molecules
from rdkit.Chem.Draw.MolDrawing import MolDrawing, DrawingOptions #Only needed if modifying defaults
from rdkit.Chem import PyMol
# Out:
# RDKit WARNING: [22:10:18] Enabling RDKit 2019.09.3 jupyter extensions

# %%
data_full1 = pd.read_csv('fulldb1.txt', sep="	", header=0)

# %%
patt1 = Chem.MolFromSmarts('C(c)=C(c)')
patt2 = Chem.MolFromSmarts('N(c)=N(c)')

# %%
#Divide the whole sets into small batches
samplesize=100000
samplenum=len(data_full1)//samplesize+1

# %%
all_DataFrame_A=[]
all_DataFrame_D=[]
version_id_A =[]
version_id_D = []
parent_id_A = []
parent_id_D = []
logfile=open('logfile.txt','w')
#iterate the set to find compounds with certain functional groups
for i in range(samplenum):
    if i==samplenum-1:
        data_segment_1=data_full1.loc[samplesize*i:]
    else:
        data_segment_1 = data_full1.loc[samplesize*i:samplesize*(i+1)]
    start = time.time()
    
    print('Batch no. {:d}'.format(i), end="  ")

    suppl = data_segment_1['isosmiles'].tolist()
    supp2 = data_segment_1['version_id'].tolist()
    supp3 = data_segment_1['parent_id'].tolist()
    ms = []
    for smi in suppl:
        try: 
            ms.append(Chem.MolFromSmiles(smi))
        except:
            ms.append(None)
            
    ms_filter = list(filter(None, ms)) 
    id_filter1 = list(filter(None, supp2)) 
    id_filter2 = list(filter(None, supp3))
    matches_1d = []
    matches_1a = []
    indices1d = []
    indices1a = []
    for i,mol in enumerate(ms_filter):
        if mol.HasSubstructMatch(patt1):
            matches_1d.append(mol)
            indices1d.append(i)
        if mol.HasSubstructMatch(patt2):
            matches_1a.append(mol)
            indices1a.append(i)
    id_final1d = []
    id_final1a = []
    id_final2d = []
    id_final2a = []
    for i in indices1d:
        id_final1d.append(id_filter1[i])
        id_final2d.append(id_filter2[i])
    for i in indices1a:
        id_final2a.append(id_filter2[i])
        id_final1a.append(id_filter1[i])
        
    
    logfile.write('Batch number {:>20d}\n'.format(i))
    logfile.write('Number of Diarylethene matches: {:>8d}\n'.format(len(matches_1d)))
    logfile.write('Number of Azobenzene matches: {:>8d}\n'.format(len(matches_1a)))
    
    smiles_D, smiles_A=[],[]
    for molecule in matches_1d:
        smiles=Chem.MolToSmiles(molecule)
        smiles_D.append(smiles)
    for molecule in matches_1a:
        smiles=Chem.MolToSmiles(molecule)
        smiles_A.append(smiles)
    all_DataFrame_D=all_DataFrame_D+smiles_D
    all_DataFrame_A=all_DataFrame_A+smiles_A
    version_id_D = id_final1d + version_id_D
    version_id_A = id_final1a + version_id_A
    
    parent_id_A = id_final2a + parent_id_A
    parent_id_D = id_final2d + parent_id_D
    end = time.time()
    print('Finished, run time: {:>10.3f}s'.format(end - start))
all_id_D = pd.DataFrame(all_id_D)
all_id_A = pd.DataFrame(all_id_A)
all_DataFrame_A=pd.DataFrame(all_DataFrame_A)
all_DataFrame_D=pd.DataFrame(all_DataFrame_D)

Final_D = pd.concat([all_DataFrame_D,all_id_D],axis = 1)
Final_A = pd.concat([all_DataFrame_A,all_id_A],axis = 1)
Final_A.to_csv('MolPort_A_batch_1.csv')
Final_D.to_csv('MolPort_D_batch_1.csv')
logfile.close()
# Out:
# Batch no. 0  Finished, run time:     45.620s
# Batch no. 1  Finished, run time:     33.730s
# Batch no. 2  Finished, run time:     39.063s
# Batch no. 3  Finished, run time:     43.235s
# Batch no. 4  Finished, run time:     48.164s
# Batch no. 5  Finished, run time:     46.078s
# Batch no. 6  Finished, run time:     45.341s
# Batch no. 7  Finished, run time:     46.399s
# Batch no. 8  Finished, run time:     54.953s
# Batch no. 9  Finished, run time:     54.589s
# Batch no. 10  Finished, run time:     50.968s
# Batch no. 11  Finished, run time:     56.114s
# Batch no. 12  Finished, run time:     59.264s
# Batch no. 13  Finished, run time:     65.614s
# Batch no. 14  Finished, run time:     58.369s
# Batch no. 15  Finished, run time:     57.053s
# Batch no. 16  Finished, run time:     56.112s
# Batch no. 17  Finished, run time:     54.089s
# Batch no. 18  Finished, run time:     55.215s
# Batch no. 19  Finished, run time:     51.001s
# Batch no. 20  Finished, run time:     49.275s
# Batch no. 21  Finished, run time:     62.959s
# Batch no. 22  Finished, run time:     64.779s
# Batch no. 23  Finished, run time:     59.321s
# Batch no. 24  Finished, run time:     58.906s
# Batch no. 25  Finished, run time:     58.809s
# Batch no. 26  Finished, run time:     58.545s
# Batch no. 27  Finished, run time:     58.128s
# Batch no. 28  Finished, run time:     57.398s
# Batch no. 29  Finished, run time:     66.953s
# Batch no. 30  Finished, run time:     61.257s
# Batch no. 31  Finished, run time:     57.452s
# Batch no. 32  Finished, run time:     61.095s
# Batch no. 33  Finished, run time:     73.032s
# Batch no. 34  Finished, run time:     60.441s
# Batch no. 35  Finished, run time:     55.179s
# Batch no. 36  Finished, run time:     54.960s
# Batch no. 37  Finished, run time:     66.317s
# Batch no. 38  Finished, run time:     51.350s
# Batch no. 39  Finished, run time:     50.778s
# Batch no. 40  Finished, run time:     48.073s
# Batch no. 41  Finished, run time:     51.593s
# Batch no. 42  Finished, run time:     67.607s
# Batch no. 43  Finished, run time:     69.462s
# Batch no. 44  Finished, run time:     55.504s
# Batch no. 45  Finished, run time:     51.771s
# Batch no. 46  Finished, run time:     49.976s
# Batch no. 47  Finished, run time:     46.513s
# Batch no. 48  Finished, run time:     44.714s
# Batch no. 49  Finished, run time:     28.895s
# Batch no. 50  Finished, run time:     25.563s
# Batch no. 51  Finished, run time:     24.824s
# Batch no. 52  Finished, run time:     25.550s
# Batch no. 53  Finished, run time:     24.144s
# Batch no. 54  Finished, run time:     25.107s
# Batch no. 55  Finished, run time:     24.980s
# Batch no. 56  Finished, run time:     25.404s
# Batch no. 57  Finished, run time:     25.999s
# Batch no. 58  Finished, run time:     25.512s
# Batch no. 59  Finished, run time:     25.991s
# Batch no. 60  Finished, run time:     24.970s
# Batch no. 61  Finished, run time:     23.872s
# Batch no. 62  Finished, run time:     25.421s
# Batch no. 63  Finished, run time:     25.250s
# Batch no. 64  Finished, run time:     24.734s
# Batch no. 65  Finished, run time:     25.846s
# Batch no. 66  Finished, run time:     25.306s
# Batch no. 67  Finished, run time:     32.247s
# Batch no. 68  Finished, run time:     44.627s
# Batch no. 69  Finished, run time:     48.222s
# Batch no. 70  Finished, run time:     58.633s
# Batch no. 71  Finished, run time:     63.021s
# Batch no. 72  Finished, run time:     57.880s
# Batch no. 73  Finished, run time:     52.950s
# Batch no. 74  Finished, run time:     52.169s
# Batch no. 75  Finished, run time:     52.339s
# Batch no. 76  Finished, run time:     54.572s
# Batch no. 77  Finished, run time:     62.914s
# Batch no. 78  Finished, run time:     54.077s
# Batch no. 79  Finished, run time:     55.401s
# Batch no. 80  Finished, run time:     50.862s
# Batch no. 81  Finished, run time:     46.470s
# Batch no. 82  Finished, run time:     51.649s
# Batch no. 83  Finished, run time:     46.877s
# Batch no. 84  Finished, run time:     48.842s
# Batch no. 85  Finished, run time:     37.667s
# Batch no. 86  Finished, run time:     37.896s
# Batch no. 87  Finished, run time:     41.106s
# Batch no. 88  Finished, run time:     46.967s
# Batch no. 89  Finished, run time:     29.407s
# Batch no. 90  Finished, run time:     46.570s
# Batch no. 91  Finished, run time:     42.491s
# Batch no. 92  Finished, run time:     38.778s
# Batch no. 93  Finished, run time:     42.958s
# Batch no. 94  Finished, run time:     43.123s
# Batch no. 95  Finished, run time:     42.311s
# Batch no. 96  Finished, run time:     45.557s
# Batch no. 97  Finished, run time:     26.331s
# Batch no. 98  Finished, run time:     22.579s
# Batch no. 99  Finished, run time:     33.658s
# Batch no. 100  Finished, run time:     45.633s
# Batch no. 101  Finished, run time:     48.329s
# Batch no. 102  Finished, run time:     51.491s
# Batch no. 103  Finished, run time:     53.088s
# Batch no. 104  Finished, run time:     50.544s
# Batch no. 105  Finished, run time:     51.288s
# Batch no. 106  Finished, run time:     47.179s
# Batch no. 107  Finished, run time:     37.051s
# Batch no. 108  Finished, run time:     30.594s
# Batch no. 109  Finished, run time:     24.181s
# Batch no. 110  Finished, run time:     23.940s
# Batch no. 111  Finished, run time:     33.691s
# Batch no. 112  Finished, run time:     38.163s
# Batch no. 113  Finished, run time:     41.193s
# Batch no. 114  Finished, run time:     42.532s
# Batch no. 115  Finished, run time:     26.984s
# Batch no. 116  Finished, run time:     46.742s
# Batch no. 117  Finished, run time:     43.651s
# Batch no. 118  Finished, run time:     59.476s
# Batch no. 119  Finished, run time:     53.913s
# Batch no. 120  Finished, run time:     51.443s
# Batch no. 121  Finished, run time:     49.597s
# Batch no. 122  Finished, run time:     48.401s
# Batch no. 123  Finished, run time:     44.922s
# Batch no. 124  Finished, run time:     47.467s
# Batch no. 125  Finished, run time:     43.899s
# Batch no. 126  Finished, run time:     56.610s
# Batch no. 127  Finished, run time:     66.086s
# Batch no. 128  Finished, run time:     77.967s
# Batch no. 129  Finished, run time:     74.080s
# Batch no. 130  Finished, run time:     51.446s
# Batch no. 131  Finished, run time:     54.072s
# Batch no. 132  Finished, run time:     52.151s
# Batch no. 133  Finished, run time:     56.928s
# Batch no. 134  Finished, run time:     57.435s
# Batch no. 135  Finished, run time:     59.400s
# Batch no. 136  Finished, run time:     49.796s
# Batch no. 137  Finished, run time:     48.696s
# Batch no. 138  Finished, run time:     58.647s
# Batch no. 139  Finished, run time:     79.073s
# Batch no. 140  Finished, run time:     91.932s
# Batch no. 141  Finished, run time:    100.532s
# Batch no. 142  Finished, run time:     66.419s
# Batch no. 143  Finished, run time:     63.573s
# Batch no. 144  Finished, run time:     42.385s
# Batch no. 145  Finished, run time:     47.023s
# Batch no. 146  Finished, run time:     52.597s
# Batch no. 147  Finished, run time:     49.120s
# Batch no. 148  Finished, run time:     34.154s
# Batch no. 149  Finished, run time:     30.901s
# Batch no. 150  Finished, run time:     28.862s
# Batch no. 151  Finished, run time:     22.617s
# Batch no. 152  Finished, run time:     26.471s
# Batch no. 153  Finished, run time:     47.470s
# Batch no. 154  Finished, run time:     45.500s
# Batch no. 155  Finished, run time:     47.825s
# Batch no. 156  Finished, run time:     51.771s
# Batch no. 157  Finished, run time:     43.887s
# Batch no. 158  Finished, run time:     41.429s
# Batch no. 159  Finished, run time:     44.558s
# Batch no. 160  Finished, run time:     41.338s
# Batch no. 161  Finished, run time:     41.821s
# Batch no. 162  Finished, run time:     43.969s
# Batch no. 163  Finished, run time:     40.925s
# Batch no. 164  Finished, run time:     43.983s
# Batch no. 165  Finished, run time:     32.617s
# Batch no. 166  Finished, run time:     26.855s
# Batch no. 167  Finished, run time:     29.097s
# Batch no. 168  Finished, run time:     28.237s
# Batch no. 169  Finished, run time:     23.653s
# Batch no. 170  Finished, run time:     31.094s
# Batch no. 171  Finished, run time:     26.854s
# Batch no. 172  Finished, run time:     26.900s
# Batch no. 173  Finished, run time:     30.326s
# Batch no. 174  Finished, run time:     32.195s
# Batch no. 175  Finished, run time:     29.266s
# Batch no. 176  Finished, run time:     27.783s
# Batch no. 177  Finished, run time:     30.481s
# Batch no. 178  Finished, run time:     31.195s
# Batch no. 179  Finished, run time:     31.309s
# Batch no. 180  Finished, run time:     30.733s
# Batch no. 181  Finished, run time:     31.586s
# Batch no. 182  Finished, run time:     31.200s
# Batch no. 183  Finished, run time:     30.449s
# Batch no. 184  Finished, run time:     29.179s
# Batch no. 185  Finished, run time:     30.723s
# Batch no. 186  Finished, run time:     30.339s
# Batch no. 187  Finished, run time:     31.366s
# Batch no. 188  Finished, run time:     29.674s
# Batch no. 189  Finished, run time:     28.971s
# Batch no. 190  Finished, run time:     28.963s
# Batch no. 191  Finished, run time:     29.783s
# Batch no. 192  Finished, run time:     39.760s
# Batch no. 193  Finished, run time:     48.365s
# Batch no. 194  Finished, run time:     50.007s
# Batch no. 195  Finished, run time:     50.010s
# Batch no. 196  Finished, run time:     48.569s
# Batch no. 197  Finished, run time:     47.463s
# Batch no. 198  Finished, run time:     48.612s
# Batch no. 199  Finished, run time:     51.753s
# Batch no. 200  Finished, run time:     30.897s
# Batch no. 201  Finished, run time:     31.277s
# Batch no. 202  Finished, run time:     41.301s
# Batch no. 203  Finished, run time:     43.906s
# Batch no. 204  Finished, run time:     47.765s
# Batch no. 205  Finished, run time:     47.390s
# Batch no. 206  Finished, run time:     47.530s
# Batch no. 207  Finished, run time:     46.573s
# Batch no. 208  Finished, run time:     46.900s
# Batch no. 209  Finished, run time:     47.206s
# Batch no. 210  Finished, run time:     46.621s
# Batch no. 211  Finished, run time:     45.402s
# Batch no. 212  Finished, run time:     45.325s
# Batch no. 213  Finished, run time:     45.789s
# Batch no. 214  Finished, run time:     45.400s
# Batch no. 215  Finished, run time:     45.753s
# Batch no. 216  Finished, run time:     45.541s
# Batch no. 217  Finished, run time:     45.301s
# Batch no. 218  Finished, run time:     46.048s
# Batch no. 219  Finished, run time:     46.700s
# Batch no. 220  Finished, run time:     46.627s
# Batch no. 221  Finished, run time:     48.356s
# Batch no. 222  Finished, run time:     48.645s
# Batch no. 223  Finished, run time:     49.578s
# Batch no. 224  Finished, run time:     50.745s
# Batch no. 225  Finished, run time:     53.760s
# Batch no. 226  Finished, run time:     58.503s
# Batch no. 227  Finished, run time:     55.058s
# Batch no. 228  Finished, run time:     61.356s
# Batch no. 229  Finished, run time:     72.046s
# Batch no. 230  Finished, run time:     59.323s
# Batch no. 231  Finished, run time:     58.641s
# Batch no. 232  Finished, run time:     57.468s
# Batch no. 233  Finished, run time:     61.211s
# Batch no. 234  Finished, run time:     65.149s
# Batch no. 235  Finished, run time:     66.495s
# Batch no. 236  Finished, run time:     62.865s
# Batch no. 237  Finished, run time:     63.778s
# Batch no. 238  Finished, run time:     68.297s
# Batch no. 239  Finished, run time:     73.614s
# Batch no. 240  Finished, run time:     74.614s
# Batch no. 241  Finished, run time:     66.789s
# Batch no. 242  Finished, run time:     61.074s
# Batch no. 243  Finished, run time:     66.967s
# Batch no. 244  Finished, run time:     64.631s
# Batch no. 245  Finished, run time:     64.207s
# Batch no. 246  Finished, run time:     63.098s
# Batch no. 247  Finished, run time:     62.781s
# Batch no. 248  Finished, run time:     57.429s
# Batch no. 249  Finished, run time:     53.809s
# Batch no. 250  Finished, run time:     61.234s
# Batch no. 251  Finished, run time:     63.894s
# Batch no. 252  Finished, run time:     64.113s
# Batch no. 253  Finished, run time:     58.365s
# Batch no. 254  Finished, run time:     63.503s
# Batch no. 255  Finished, run time:     63.632s
# Batch no. 256  Finished, run time:     57.681s
# Batch no. 257  Finished, run time:     51.881s
# Batch no. 258  Finished, run time:     52.514s
# Batch no. 259  Finished, run time:     42.981s
# Batch no. 260  Finished, run time:     40.017s
# Batch no. 261  Finished, run time:     41.590s
# Batch no. 262  Finished, run time:     38.151s
# Batch no. 263  Finished, run time:     36.991s
# Batch no. 264  Finished, run time:     47.935s
# Batch no. 265  Finished, run time:     53.384s
# Batch no. 266  Finished, run time:     63.059s
# Batch no. 267  Finished, run time:     64.925s
# Batch no. 268  Finished, run time:     63.126s
# Batch no. 269  Finished, run time:     65.191s
# Batch no. 270  Finished, run time:     65.846s
# Batch no. 271  Finished, run time:     74.806s
# Batch no. 272  Finished, run time:     90.953s
# Batch no. 273  Finished, run time:     91.523s
# Batch no. 274  Finished, run time:     90.240s
# Batch no. 275  Finished, run time:     87.513s
# Batch no. 276  Finished, run time:     90.087s
# Batch no. 277  Finished, run time:     90.370s
# Batch no. 278  Finished, run time:     95.763s
# Batch no. 279  Finished, run time:     90.229s
# Batch no. 280  Finished, run time:     85.316s
# Batch no. 281  Finished, run time:     88.728s
# Batch no. 282  Finished, run time:     87.731s
# Batch no. 283  Finished, run time:     79.042s
# Batch no. 284  Finished, run time:     81.956s
# Batch no. 285  Finished, run time:     81.569s
# Batch no. 286  Finished, run time:     88.132s
# Batch no. 287  Finished, run time:     86.954s
# Batch no. 288  Finished, run time:     93.173s
# Batch no. 289  Finished, run time:     96.703s
# Batch no. 290  Finished, run time:     96.966s
# Batch no. 291  Finished, run time:     78.876s
# Batch no. 292  Finished, run time:     64.138s
# Batch no. 293  Finished, run time:     54.069s
# Batch no. 294  Finished, run time:     49.356s
# Batch no. 295  Finished, run time:     49.421s
# Batch no. 296  Finished, run time:     53.411s
# Batch no. 297  Finished, run time:     54.305s
# Batch no. 298  Finished, run time:     58.546s
# Batch no. 299  Finished, run time:     67.027s
# Batch no. 300  Finished, run time:     75.226s
# Batch no. 301  Finished, run time:     82.640s
# Batch no. 302  Finished, run time:     91.179s
# Batch no. 303  Finished, run time:     96.342s
# Batch no. 304  Finished, run time:     90.798s
# Batch no. 305  Finished, run time:     71.789s
# Batch no. 306  Finished, run time:     81.244s
# Batch no. 307  Finished, run time:     96.425s
# Batch no. 308  Finished, run time:    102.829s
# Batch no. 309  Finished, run time:     87.421s
# Batch no. 310  Finished, run time:     82.390s
# Batch no. 311  Finished, run time:     98.702s
# Batch no. 312  Finished, run time:    101.512s
# Batch no. 313  Finished, run time:     56.874s
# Batch no. 314  Finished, run time:     45.501s
# Batch no. 315  Finished, run time:     79.413s
# Batch no. 316  Finished, run time:     64.231s
# Batch no. 317  Finished, run time:     35.109s
# Batch no. 318  Finished, run time:     39.459s
# Batch no. 319  Finished, run time:     41.607s
# Batch no. 320  Finished, run time:     40.824s
# Batch no. 321  Finished, run time:     44.932s
# Batch no. 322  Finished, run time:     44.651s
# Batch no. 323  Finished, run time:     44.322s
# Batch no. 324  Finished, run time:     51.204s
# Batch no. 325  Finished, run time:     53.045s
# Batch no. 326  Finished, run time:     63.220s
# Batch no. 327  Finished, run time:     68.738s
# Batch no. 328  Finished, run time:     69.013s
# Batch no. 329  Finished, run time:     69.732s
# Batch no. 330  Finished, run time:     68.577s
# Batch no. 331  Finished, run time:     67.775s
# Batch no. 332  Finished, run time:     73.530s
# Batch no. 333  Finished, run time:     76.252s
# Batch no. 334  Finished, run time:     78.280s
# Batch no. 335  Finished, run time:     74.655s
# Batch no. 336  Finished, run time:     78.707s
# Batch no. 337  Finished, run time:     81.255s
# Batch no. 338  Finished, run time:     69.755s
# Batch no. 339  Finished, run time:     79.378s
# Batch no. 340  Finished, run time:     74.775s
# Batch no. 341  Finished, run time:     77.693s
# Batch no. 342  Finished, run time:     75.968s
# Batch no. 343  Finished, run time:     72.285s
# Batch no. 344  Finished, run time:     82.876s
# Batch no. 345  Finished, run time:     81.406s
# Batch no. 346  Finished, run time:     65.173s
# Batch no. 347  Finished, run time:     69.439s
# Batch no. 348  Finished, run time:     75.019s
# Batch no. 349  Finished, run time:     76.036s
# Batch no. 350  Finished, run time:     80.010s
# Batch no. 351  Finished, run time:     85.490s
# Batch no. 352  Finished, run time:     92.495s
# Batch no. 353  Finished, run time:     83.672s
# Batch no. 354  Finished, run time:     75.009s
# Batch no. 355  Finished, run time:     72.535s
# Batch no. 356  Finished, run time:     62.983s
# Batch no. 357  Finished, run time:     73.494s
# Batch no. 358  Finished, run time:     62.797s
# Batch no. 359  Finished, run time:     62.697s
# Batch no. 360  Finished, run time:     76.813s
# Batch no. 361  Finished, run time:     86.376s
# Batch no. 362  Finished, run time:     80.636s
# Batch no. 363  Finished, run time:     69.634s
# Batch no. 364  Finished, run time:     71.896s
# Batch no. 365  Finished, run time:     70.417s
# Batch no. 366  Finished, run time:     77.733s
# Batch no. 367  Finished, run time:     83.179s
# Batch no. 368  Finished, run time:     43.736s

# %%
version_id_A = pd.DataFrame(version_id_A,columns=['version_id'])
version_id_D = pd.DataFrame(version_id_D,columns=['version_id'])
parent_id_A = pd.DataFrame(parent_id_A,columns=['parent_id'])
parent_id_D = pd.DataFrame(parent_id_D,columns=['parent_id'])

all_DataFrame_A=pd.DataFrame(all_DataFrame_A,columns=['isosmiles_A'])
all_DataFrame_D=pd.DataFrame(all_DataFrame_D,columns=['isosmiles_D'])

Final_D = pd.concat([all_DataFrame_D,version_id_A,parent_id_A],axis = 1)
Final_A = pd.concat([all_DataFrame_A,version_id_A,parent_id_A],axis = 1)
Final_A.to_csv('eMol_all_A_batch.csv')
Final_D.to_csv('eMol_all_D_batch.csv')
logfile.close()

# %%
Final_D.head()
# Out:
#                                          isosmiles_D   version_id    parent_id
# 0  CN(C)c1ccc(/C=C/c2nc3ccccc3c(=O)n2-c2ccc(O)cc2...  336464459.0  336464459.0
# 1  O=c1[nH]c(/C=C/c2ccc(O)cc2)c([N+](=O)[O-])c(=O...  336478551.0  336478551.0
# 2                             Cc1ccccc1/C=C/c1ccccc1  336483667.0  336483667.0
# 3                                O=C(O)C1=Cc2ccccc21  336486210.0  336486210.0
# 4              N=C(N)c1ccc(/C=C/c2ccc(C(=N)N)cc2)cc1  336488762.0  336488762.0

# %%
data_full2 = pd.read_csv('fulldb2.txt', sep="	", header=0)
print(len(data_full2))
samplenum=len(data_full2)//samplesize+1
# Out:
# 5000010

# %%
all_DataFrame_A=[]
all_DataFrame_D=[]
all_id_D = []
all_id_A = []
logfile=open('logfile.txt','w')
for i in range(samplenum):
    if i==samplenum-1:
        data_segment_1=data_full2.loc[samplesize*i:]
    else:
        data_segment_1 = data_full2.loc[samplesize*i:samplesize*(i+1)]
    start = time.time()
    
    print('Batch no. {:d}'.format(i), end="  ")

    suppl = data_segment_1['SMILES'].tolist()
    supp2 = data_segment_1['MOLPORTID'].tolist()
    ms = []
    for smi in suppl:
        try: 
            ms.append(Chem.MolFromSmiles(smi))
        except:
            ms.append(None)
    ms_filter = list(filter(None, ms)) 
    id_filter = list(filter(None, supp2))
    indices1 = []
    indices2 = []
    matches_1d = []
    matches_1a = []
    
    for i,mol in enumerate(ms_filter):
        if mol.HasSubstructMatch(patt1):
            matches_1d.append(mol)
            indices1.append(i)
        if mol.HasSubstructMatch(patt2):
            matches_1a.append(mol)
            indices2.append(i)
    id_final1 = []
    id_final2 = []
    for i in indices1:
        id_final1.append(id_filter[i])
    for i in indices2:
        id_final2.append(id_filter[i])

    
    logfile.write('Batch number {:>20d}\n'.format(i))
    logfile.write('Number of Diarylethene matches: {:>8d}\n'.format(len(matches_1d)))
    logfile.write('Number of Azobenzene matches: {:>8d}\n'.format(len(matches_1a)))
    
    smiles_D, smiles_A=[],[]
    for molecule in matches_1d:
        smiles=Chem.MolToSmiles(molecule)
        smiles_D.append(smiles)
    for molecule in matches_1a:
        smiles=Chem.MolToSmiles(molecule)
        smiles_A.append(smiles)
    all_DataFrame_D=all_DataFrame_D+smiles_D
    all_DataFrame_A=all_DataFrame_A+smiles_A
    all_id_D = id_final1 + all_id_D
    all_id_A = id_final2 + all_id_A
    end = time.time()
    print('Finished, run time: {:>10.3f}s'.format(end - start))
all_id_D = pd.DataFrame(all_id_D)
all_id_A = pd.DataFrame(all_id_A)
all_DataFrame_A=pd.DataFrame(all_DataFrame_A)
all_DataFrame_D=pd.DataFrame(all_DataFrame_D)

Final_D = pd.concat([all_DataFrame_D,all_id_D],axis = 1)
Final_A = pd.concat([all_DataFrame_A,all_id_A],axis = 1)
Final_A.to_csv('MolPort_A_batch_2.csv')
Final_D.to_csv('MolPort_D_batch_2.csv')
logfile.close()
# Out:
# Batch no. 0  Finished, run time:     44.042s
# Batch no. 1  Finished, run time:     49.687s
# Batch no. 2  Finished, run time:     55.276s
# Batch no. 3  Finished, run time:     61.109s
# Batch no. 4  Finished, run time:     53.748s
# Batch no. 5  Finished, run time:     50.768s
# Batch no. 6  Finished, run time:     57.050s
# Batch no. 7  Finished, run time:     61.799s
# Batch no. 8  Finished, run time:     75.251s
# Batch no. 9  Finished, run time:     72.282s
# Batch no. 10  Finished, run time:     64.802s
# Batch no. 11  Finished, run time:     56.189s
# Batch no. 12  Finished, run time:     56.447s
# Batch no. 13  Finished, run time:     56.700s
# Batch no. 14  Finished, run time:     61.174s
# Batch no. 15  Finished, run time:     60.956s
# Batch no. 16  Finished, run time:     61.172s
# Batch no. 17  Finished, run time:     58.681s
# Batch no. 18  Finished, run time:     61.364s
# Batch no. 19  Finished, run time:     65.873s
# Batch no. 20  Finished, run time:     66.785s
# Batch no. 21  Finished, run time:     87.926s
# Batch no. 22  Finished, run time:     85.368s
# Batch no. 23  Finished, run time:     67.071s
# Batch no. 24  Finished, run time:     63.255s
# Batch no. 25  Finished, run time:     62.509s
# Batch no. 26  Finished, run time:     58.482s
# Batch no. 27  Finished, run time:     54.348s
# Batch no. 28  Finished, run time:     41.335s
# Batch no. 29  Finished, run time:     31.286s
# Batch no. 30  Finished, run time:     29.829s
# Batch no. 31  Finished, run time:     38.236s
# Batch no. 32  Finished, run time:     40.623s
# Batch no. 33  Finished, run time:     43.419s
# Batch no. 34  Finished, run time:     46.268s
# Batch no. 35  Finished, run time:     50.158s
# Batch no. 36  Finished, run time:     49.522s
# Batch no. 37  Finished, run time:     54.316s
# Batch no. 38  Finished, run time:     47.504s
# Batch no. 39  Finished, run time:     52.991s
# Batch no. 40  Finished, run time:     52.588s
# Batch no. 41  Finished, run time:     53.635s
# Batch no. 42  Finished, run time:     54.763s
# Batch no. 43  Finished, run time:     57.705s
# Batch no. 44  Finished, run time:     54.104s
# Batch no. 45  Finished, run time:     54.812s
# Batch no. 46  Finished, run time:     58.484s
# Batch no. 47  Finished, run time:     59.718s
# Batch no. 48  Finished, run time:     64.138s
# Batch no. 49  Finished, run time:     67.116s
# Batch no. 50  Finished, run time:     14.970s

# %%
data_full3 = pd.read_csv('fulldb3.txt', sep="	", header=0)
print(len(data_full3))
samplenum=len(data_full3)//samplesize+1
# Out:
# 5000009

# %%
all_DataFrame_A=[]
all_DataFrame_D=[]
all_id_D = []
all_id_A = []
logfile=open('logfile.txt','w')
for i in range(samplenum):
    if i==samplenum-1:
        data_segment_1=data_full3.loc[samplesize*i:]
    else:
        data_segment_1 = data_full3.loc[samplesize*i:samplesize*(i+1)]
    start = time.time()
    
    print('Batch no. {:d}'.format(i), end="  ")

    suppl = data_segment_1['SMILES'].tolist()
    supp2 = data_segment_1['MOLPORTID'].tolist()
    ms = []
    for smi in suppl:
        try: 
            ms.append(Chem.MolFromSmiles(smi))
        except:
            ms.append(None)
    ms_filter = list(filter(None, ms)) 
    id_filter = list(filter(None, supp2))
    indices1 = []
    indices2 = []
    matches_1d = []
    matches_1a = []
    
    for i,mol in enumerate(ms_filter):
        if mol.HasSubstructMatch(patt1):
            matches_1d.append(mol)
            indices1.append(i)
        if mol.HasSubstructMatch(patt2):
            matches_1a.append(mol)
            indices2.append(i)
    id_final1 = []
    id_final2 = []
    for i in indices1:
        id_final1.append(id_filter[i])
    for i in indices2:
        id_final2.append(id_filter[i])


    
    logfile.write('Batch number {:>20d}\n'.format(i))
    logfile.write('Number of Diarylethene matches: {:>8d}\n'.format(len(matches_1d)))
    logfile.write('Number of Azobenzene matches: {:>8d}\n'.format(len(matches_1a)))
    
    smiles_D, smiles_A=[],[]
    for molecule in matches_1d:
        smiles=Chem.MolToSmiles(molecule)
        smiles_D.append(smiles)
    for molecule in matches_1a:
        smiles=Chem.MolToSmiles(molecule)
        smiles_A.append(smiles)
    all_DataFrame_D=all_DataFrame_D+smiles_D
    all_DataFrame_A=all_DataFrame_A+smiles_A
    all_id_D = id_final1 + all_id_D
    all_id_A = id_final2 + all_id_A
    end = time.time()
    print('Finished, run time: {:>10.3f}s'.format(end - start))
all_id_D = pd.DataFrame(all_id_D)
all_id_A = pd.DataFrame(all_id_A)
all_DataFrame_A=pd.DataFrame(all_DataFrame_A)
all_DataFrame_D=pd.DataFrame(all_DataFrame_D)

Final_D = pd.concat([all_DataFrame_D,all_id_D],axis = 1)
Final_A = pd.concat([all_DataFrame_A,all_id_A],axis = 1)
Final_A.to_csv('MolPort_A_batch_3.csv')
Final_D.to_csv('MolPort_D_batch_3.csv')
logfile.close()
# Out:
# Batch no. 0  Finished, run time:     53.949s
# Batch no. 1  Finished, run time:     63.953s
# Batch no. 2  Finished, run time:     63.550s
# Batch no. 3  Finished, run time:     42.917s
# Batch no. 4  Finished, run time:     35.643s
# Batch no. 5  Finished, run time:     36.509s
# Batch no. 6  Finished, run time:     29.809s
# Batch no. 7  Finished, run time:     28.345s
# Batch no. 8  Finished, run time:     30.473s
# Batch no. 9  Finished, run time:     30.628s
# Batch no. 10  Finished, run time:     30.515s
# Batch no. 11  Finished, run time:     30.675s
# Batch no. 12  Finished, run time:     30.092s
# Batch no. 13  Finished, run time:     33.720s
# Batch no. 14  Finished, run time:     32.616s
# Batch no. 15  Finished, run time:     28.803s
# Batch no. 16  Finished, run time:     29.977s
# Batch no. 17  Finished, run time:     29.604s
# Batch no. 18  Finished, run time:     27.038s
# Batch no. 19  Finished, run time:     29.306s
# Batch no. 20  Finished, run time:     28.632s
# Batch no. 21  Finished, run time:     29.217s
# Batch no. 22  Finished, run time:     28.158s
# Batch no. 23  Finished, run time:     29.569s
# Batch no. 24  Finished, run time:     28.110s
# Batch no. 25  Finished, run time:     31.003s
# Batch no. 26  Finished, run time:     29.799s
# Batch no. 27  Finished, run time:     30.768s
# Batch no. 28  Finished, run time:     29.312s
# Batch no. 29  Finished, run time:     29.938s
# Batch no. 30  Finished, run time:     29.698s
# Batch no. 31  Finished, run time:     28.551s
# Batch no. 32  Finished, run time:     28.226s
# Batch no. 33  Finished, run time:     29.775s
# Batch no. 34  Finished, run time:     28.643s
# Batch no. 35  Finished, run time:     28.836s
# Batch no. 36  Finished, run time:     29.582s
# Batch no. 37  Finished, run time:     30.511s
# Batch no. 38  Finished, run time:     30.222s
# Batch no. 39  Finished, run time:     31.255s
# Batch no. 40  Finished, run time:     29.612s
# Batch no. 41  Finished, run time:     33.131s
# Batch no. 42  Finished, run time:     29.363s
# Batch no. 43  Finished, run time:     31.130s
# Batch no. 44  Finished, run time:     33.874s
# Batch no. 45  Finished, run time:     49.077s
# Batch no. 46  Finished, run time:     54.478s
# Batch no. 47  Finished, run time:     62.477s
# Batch no. 48  Finished, run time:     61.665s
# Batch no. 49  Finished, run time:     59.676s
# Batch no. 50  Finished, run time:     13.421s

# %%
data_full4 = pd.read_csv('fulldb4.txt', sep="	", header=0)
print(len(data_full4))
samplesize=100000
samplenum=len(data_full4)//samplesize+1
# Out:
# 5000095

# %%
all_DataFrame_A=[]
all_DataFrame_D=[]
all_id_D = []
all_id_A = []
logfile=open('logfile.txt','w')
for i in range(samplenum):
    if i==samplenum-1:
        data_segment_1=data_full4.loc[samplesize*i:]
    else:
        data_segment_1 = data_full4.loc[samplesize*i:samplesize*(i+1)]
    start = time.time()
    
    print('Batch no. {:d}'.format(i), end="  ")

    suppl = data_segment_1['SMILES'].tolist()
    supp2 = data_segment_1['MOLPORTID'].tolist()
    ms = []
    for smi in suppl:
        try: 
            ms.append(Chem.MolFromSmiles(smi))
        except:
            ms.append(None)
    ms_filter = list(filter(None, ms)) 
    id_filter = list(filter(None, supp2))
    indices1 = []
    indices2 = []
    matches_1d = []
    matches_1a = []
    
    for i,mol in enumerate(ms_filter):
        if mol.HasSubstructMatch(patt1):
            matches_1d.append(mol)
            indices1.append(i)
        if mol.HasSubstructMatch(patt2):
            matches_1a.append(mol)
            indices2.append(i)
    id_final1 = []
    id_final2 = []
    for i in indices1:
        id_final1.append(id_filter[i])
    for i in indices2:
        id_final2.append(id_filter[i])

    
    logfile.write('Batch number {:>20d}\n'.format(i))
    logfile.write('Number of Diarylethene matches: {:>8d}\n'.format(len(matches_1d)))
    logfile.write('Number of Azobenzene matches: {:>8d}\n'.format(len(matches_1a)))
    
    smiles_D, smiles_A=[],[]
    for molecule in matches_1d:
        smiles=Chem.MolToSmiles(molecule)
        smiles_D.append(smiles)
    for molecule in matches_1a:
        smiles=Chem.MolToSmiles(molecule)
        smiles_A.append(smiles)
    all_DataFrame_D=all_DataFrame_D+smiles_D
    all_DataFrame_A=all_DataFrame_A+smiles_A
    all_id_D = id_final1 + all_id_D
    all_id_A = id_final2 + all_id_A
    end = time.time()
    print('Finished, run time: {:>10.3f}s'.format(end - start))
all_id_D = pd.DataFrame(all_id_D)
all_id_A = pd.DataFrame(all_id_A)
all_DataFrame_A=pd.DataFrame(all_DataFrame_A)
all_DataFrame_D=pd.DataFrame(all_DataFrame_D)

Final_D = pd.concat([all_DataFrame_D,all_id_D],axis = 1)
Final_A = pd.concat([all_DataFrame_A,all_id_A],axis = 1)
Final_A.to_csv('MolPort_A_batch_4.csv')
Final_D.to_csv('MolPort_D_batch_4.csv')
logfile.close()
# Out:
# Batch no. 0  Finished, run time:     39.239s
# Batch no. 1  Finished, run time:     44.781s
# Batch no. 2  Finished, run time:     51.978s
# Batch no. 3  Finished, run time:     53.088s
# Batch no. 4  Finished, run time:     56.632s
# Batch no. 5  Finished, run time:     53.822s
# Batch no. 6  Finished, run time:     58.106s
# Batch no. 7  Finished, run time:     54.003s
# Batch no. 8  Finished, run time:     50.487s
# Batch no. 9  Finished, run time:     48.898s
# Batch no. 10  Finished, run time:     55.171s
# Batch no. 11  Finished, run time:     53.293s
# Batch no. 12  Finished, run time:     65.908s
# Batch no. 13  Finished, run time:     68.302s
# Batch no. 14  Finished, run time:     67.111s
# Batch no. 15  Finished, run time:     68.122s
# Batch no. 16  Finished, run time:    113.924s
# Batch no. 17  Finished, run time:    144.987s
# Batch no. 18  Finished, run time:    153.837s
# Batch no. 19  Finished, run time:    151.933s
# Batch no. 20  Finished, run time:    147.298s
# Batch no. 21  Finished, run time:    141.199s
# Batch no. 22  Finished, run time:    147.207s
# Batch no. 23  Finished, run time:    118.359s
# Batch no. 24  Finished, run time:     77.870s
# Batch no. 25  Finished, run time:     67.865s
# Batch no. 26  Finished, run time:     67.494s
# Batch no. 27  Finished, run time:     75.158s
# Batch no. 28  Finished, run time:     61.981s
# Batch no. 29  Finished, run time:     63.799s
# Batch no. 30  Finished, run time:     69.310s
# Batch no. 31  Finished, run time:     61.904s
# Batch no. 32  Finished, run time:     61.209s
# Batch no. 33  Finished, run time:     74.292s
# Batch no. 34  Finished, run time:     66.972s
# Batch no. 35  Finished, run time:     71.611s
# Batch no. 36  Finished, run time:     54.202s
# Batch no. 37  Finished, run time:     64.971s
# Batch no. 38  Finished, run time:     75.447s
# Batch no. 39  Finished, run time:     69.439s
# Batch no. 40  Finished, run time:     62.712s
# Batch no. 41  Finished, run time:     57.211s
# Batch no. 42  Finished, run time:     51.716s
# Batch no. 43  Finished, run time:     47.151s
# Batch no. 44  Finished, run time:     47.359s
# Batch no. 45  Finished, run time:     52.541s
# Batch no. 46  Finished, run time:     36.423s
# Batch no. 47  Finished, run time:     32.203s
# Batch no. 48  Finished, run time:     31.829s
# Batch no. 49  Finished, run time:     32.021s
# Batch no. 50  Finished, run time:      8.598s

# %%
data_full5 = pd.read_csv('fulldb5.txt', sep="	", header=0)
print(len(data_full5))
samplenum=len(data_full5)//samplesize+1
# Out:
# 5000009

# %%
all_DataFrame_A=[]
all_DataFrame_D=[]
all_id_D = []
all_id_A = []
logfile=open('logfile.txt','w')
for i in range(samplenum):
    if i==samplenum-1:
        data_segment_1=data_full5.loc[samplesize*i:]
    else:
        data_segment_1 = data_full5.loc[samplesize*i:samplesize*(i+1)]
    start = time.time()
    
    print('Batch no. {:d}'.format(i), end="  ")

    suppl = data_segment_1['SMILES'].tolist()
    supp2 = data_segment_1['MOLPORTID'].tolist()
    ms = []
    for smi in suppl:
        try: 
            ms.append(Chem.MolFromSmiles(smi))
        except:
            ms.append(None)
    ms_filter = list(filter(None, ms)) 
    id_filter = list(filter(None, supp2))
    indices1 = []
    indices2 = []
    matches_1d = []
    matches_1a = []
    
    for i,mol in enumerate(ms_filter):
        if mol.HasSubstructMatch(patt1):
            matches_1d.append(mol)
            indices1.append(i)
        if mol.HasSubstructMatch(patt2):
            matches_1a.append(mol)
            indices2.append(i)
    id_final1 = []
    id_final2 = []
    for i in indices1:
        id_final1.append(id_filter[i])
    for i in indices2:
        id_final2.append(id_filter[i])

    
    logfile.write('Batch number {:>20d}\n'.format(i))
    logfile.write('Number of Diarylethene matches: {:>8d}\n'.format(len(matches_1d)))
    logfile.write('Number of Azobenzene matches: {:>8d}\n'.format(len(matches_1a)))
    
    smiles_D, smiles_A=[],[]
    for molecule in matches_1d:
        smiles=Chem.MolToSmiles(molecule)
        smiles_D.append(smiles)
    for molecule in matches_1a:
        smiles=Chem.MolToSmiles(molecule)
        smiles_A.append(smiles)
    all_DataFrame_D=all_DataFrame_D+smiles_D
    all_DataFrame_A=all_DataFrame_A+smiles_A
    all_id_D = id_final1 + all_id_D
    all_id_A = id_final2 + all_id_A
    end = time.time()
    print('Finished, run time: {:>10.3f}s'.format(end - start))
all_id_D = pd.DataFrame(all_id_D)
all_id_A = pd.DataFrame(all_id_A)
all_DataFrame_A=pd.DataFrame(all_DataFrame_A)
all_DataFrame_D=pd.DataFrame(all_DataFrame_D)

Final_D = pd.concat([all_DataFrame_D,all_id_D],axis = 1)
Final_A = pd.concat([all_DataFrame_A,all_id_A],axis = 1)
Final_A.to_csv('MolPort_A_batch_5.csv')
Final_D.to_csv('MolPort_D_batch_5.csv')
logfile.close()
# Out:
# Batch no. 0  Finished, run time:     18.407s
# Batch no. 1  Finished, run time:     24.120s
# Batch no. 2  Finished, run time:     20.466s
# Batch no. 3  Finished, run time:     19.782s
# Batch no. 4  Finished, run time:     19.768s
# Batch no. 5  Finished, run time:     20.201s
# Batch no. 6  Finished, run time:     20.078s
# Batch no. 7  Finished, run time:     23.644s
# Batch no. 8  Finished, run time:     21.748s
# Batch no. 9  Finished, run time:     20.850s
# Batch no. 10  Finished, run time:     27.520s
# Batch no. 11  Finished, run time:     25.860s
# Batch no. 12  Finished, run time:     26.311s
# Batch no. 13  Finished, run time:     23.215s
# Batch no. 14  Finished, run time:     22.228s
# Batch no. 15  Finished, run time:     21.201s
# Batch no. 16  Finished, run time:     23.210s
# Batch no. 17  Finished, run time:     22.102s
# Batch no. 18  Finished, run time:     22.856s
# Batch no. 19  Finished, run time:     25.998s
# Batch no. 20  Finished, run time:     26.438s
# Batch no. 21  Finished, run time:     25.257s
# Batch no. 22  Finished, run time:     23.438s
# Batch no. 23  Finished, run time:     25.061s
# Batch no. 24  Finished, run time:     30.191s
# Batch no. 25  Finished, run time:     42.310s
# Batch no. 26  Finished, run time:     35.466s
# Batch no. 27  Finished, run time:     30.568s
# Batch no. 28  Finished, run time:     28.577s
# Batch no. 29  Finished, run time:     27.910s
# Batch no. 30  Finished, run time:     30.281s
# Batch no. 31  Finished, run time:     31.518s
# Batch no. 32  Finished, run time:     26.074s
# Batch no. 33  Finished, run time:     28.233s
# Batch no. 34  Finished, run time:     28.243s
# Batch no. 35  Finished, run time:     30.036s
# Batch no. 36  Finished, run time:     28.802s
# Batch no. 37  Finished, run time:     29.200s
# Batch no. 38  Finished, run time:     28.767s
# Batch no. 39  Finished, run time:     27.942s
# Batch no. 40  Finished, run time:     26.703s
# Batch no. 41  Finished, run time:     26.977s
# Batch no. 42  Finished, run time:     27.426s
# Batch no. 43  Finished, run time:     28.105s
# Batch no. 44  Finished, run time:     28.471s
# Batch no. 45  Finished, run time:     28.747s
# Batch no. 46  Finished, run time:     27.634s
# Batch no. 47  Finished, run time:     27.018s
# Batch no. 48  Finished, run time:     28.606s
# Batch no. 49  Finished, run time:     28.414s
# Batch no. 50  Finished, run time:      5.333s

# %%
data_full6 = pd.read_csv('fulldb6.txt', sep="	", header=0)
print(len(data_full6))
samplenum=len(data_full6)//samplesize+1
# Out:
# 5000015

# %%
all_DataFrame_A=[]
all_DataFrame_D=[]
all_id_D = []
all_id_A = []
logfile=open('logfile.txt','w')
for i in range(samplenum):
    if i==samplenum-1:
        data_segment_1=data_full6.loc[samplesize*i:]
    else:
        data_segment_1 = data_full6.loc[samplesize*i:samplesize*(i+1)]
    start = time.time()
    
    print('Batch no. {:d}'.format(i), end="  ")

    suppl = data_segment_1['SMILES'].tolist()
    supp2 = data_segment_1['MOLPORTID'].tolist()
    ms = []
    for smi in suppl:
        try: 
            ms.append(Chem.MolFromSmiles(smi))
        except:
            ms.append(None)
    ms_filter = list(filter(None, ms)) 
    id_filter = list(filter(None, supp2))
    indices1 = []
    indices2 = []
    matches_1d = []
    matches_1a = []
    
    for i,mol in enumerate(ms_filter):
        if mol.HasSubstructMatch(patt1):
            matches_1d.append(mol)
            indices1.append(i)
        if mol.HasSubstructMatch(patt2):
            matches_1a.append(mol)
            indices2.append(i)
    id_final1 = []
    id_final2 = []
    for i in indices1:
        id_final1.append(id_filter[i])
    for i in indices2:
        id_final2.append(id_filter[i])

    
    logfile.write('Batch number {:>20d}\n'.format(i))
    logfile.write('Number of Diarylethene matches: {:>8d}\n'.format(len(matches_1d)))
    logfile.write('Number of Azobenzene matches: {:>8d}\n'.format(len(matches_1a)))
    
    smiles_D, smiles_A=[],[]
    for molecule in matches_1d:
        smiles=Chem.MolToSmiles(molecule)
        smiles_D.append(smiles)
    for molecule in matches_1a:
        smiles=Chem.MolToSmiles(molecule)
        smiles_A.append(smiles)
    all_DataFrame_D=all_DataFrame_D+smiles_D
    all_DataFrame_A=all_DataFrame_A+smiles_A
    all_id_D = id_final1 + all_id_D
    all_id_A = id_final2 + all_id_A
    end = time.time()
    print('Finished, run time: {:>10.3f}s'.format(end - start))
all_id_D = pd.DataFrame(all_id_D)
all_id_A = pd.DataFrame(all_id_A)
all_DataFrame_A=pd.DataFrame(all_DataFrame_A)
all_DataFrame_D=pd.DataFrame(all_DataFrame_D)

Final_D = pd.concat([all_DataFrame_D,all_id_D],axis = 1)
Final_A = pd.concat([all_DataFrame_A,all_id_A],axis = 1)
Final_A.to_csv('MolPort_A_batch_6.csv')
Final_D.to_csv('MolPort_D_batch_6.csv')
logfile.close()
# Out:
# Batch no. 0  Finished, run time:     21.541s
# Batch no. 1  Finished, run time:     27.504s
# Batch no. 2  Finished, run time:     29.427s
# Batch no. 3  Finished, run time:     28.736s
# Batch no. 4  Finished, run time:     32.935s
# Batch no. 5  Finished, run time:     30.012s
# Batch no. 6  Finished, run time:     28.002s
# Batch no. 7  Finished, run time:     26.532s
# Batch no. 8  Finished, run time:     27.433s
# Batch no. 9  Finished, run time:     25.631s
# Batch no. 10  Finished, run time:     26.229s
# Batch no. 11  Finished, run time:     25.238s
# Batch no. 12  Finished, run time:     27.724s
# Batch no. 13  Finished, run time:     27.439s
# Batch no. 14  Finished, run time:     29.406s
# Batch no. 15  Finished, run time:     26.420s
# Batch no. 16  Finished, run time:     27.972s
# Batch no. 17  Finished, run time:     26.885s
# Batch no. 18  Finished, run time:     29.449s
# Batch no. 19  Finished, run time:     33.105s
# Batch no. 20  Finished, run time:     31.245s
# Batch no. 21  Finished, run time:     43.841s
# Batch no. 22  Finished, run time:     44.699s
# Batch no. 23  Finished, run time:     45.472s
# Batch no. 24  Finished, run time:     47.376s
# Batch no. 25  Finished, run time:     43.809s
# Batch no. 26  Finished, run time:     44.482s
# Batch no. 27  Finished, run time:     46.395s
# Batch no. 28  Finished, run time:     52.402s
# Batch no. 29  Finished, run time:     38.650s
# Batch no. 30  Finished, run time:     42.933s
# Batch no. 31  Finished, run time:     49.949s
# Batch no. 32  Finished, run time:     35.864s
# Batch no. 33  Finished, run time:     26.007s
# Batch no. 34  Finished, run time:     24.908s
# Batch no. 35  Finished, run time:     26.540s
# Batch no. 36  Finished, run time:     27.473s
# Batch no. 37  Finished, run time:     26.801s
# Batch no. 38  Finished, run time:     26.568s
# Batch no. 39  Finished, run time:     27.402s
# Batch no. 40  Finished, run time:     25.800s
# Batch no. 41  Finished, run time:     32.382s
# Batch no. 42  Finished, run time:     36.970s
# Batch no. 43  Finished, run time:     33.611s
# Batch no. 44  Finished, run time:     30.682s
# Batch no. 45  Finished, run time:     30.513s
# Batch no. 46  Finished, run time:     30.152s
# Batch no. 47  Finished, run time:     30.144s
# Batch no. 48  Finished, run time:     29.173s
# Batch no. 49  Finished, run time:     30.057s
# Batch no. 50  Finished, run time:      6.199s

# %%
data_full7 = pd.read_csv('fulldb7.txt', sep="	", header=0)
print(len(data_full7))
samplenum=len(data_full7)//samplesize+1
# Out:
# 5000006

# %%
all_DataFrame_A=[]
all_DataFrame_D=[]
all_id_D = []
all_id_A = []
logfile=open('logfile.txt','w')
for i in range(samplenum):
    if i==samplenum-1:
        data_segment_1=data_full7.loc[samplesize*i:]
    else:
        data_segment_1 = data_full7.loc[samplesize*i:samplesize*(i+1)]
    start = time.time()
    
    print('Batch no. {:d}'.format(i), end="  ")

    suppl = data_segment_1['SMILES'].tolist()
    supp2 = data_segment_1['MOLPORTID'].tolist()
    ms = []
    for smi in suppl:
        try: 
            ms.append(Chem.MolFromSmiles(smi))
        except:
            ms.append(None)
    ms_filter = list(filter(None, ms)) 
    id_filter = list(filter(None, supp2))
    indices1 = []
    indices2 = []
    matches_1d = []
    matches_1a = []
    
    for i,mol in enumerate(ms_filter):
        if mol.HasSubstructMatch(patt1):
            matches_1d.append(mol)
            indices1.append(i)
        if mol.HasSubstructMatch(patt2):
            matches_1a.append(mol)
            indices2.append(i)
    id_final1 = []
    id_final2 = []
    for i in indices1:
        id_final1.append(id_filter[i])
    for i in indices2:
        id_final2.append(id_filter[i])

    
    logfile.write('Batch number {:>20d}\n'.format(i))
    logfile.write('Number of Diarylethene matches: {:>8d}\n'.format(len(matches_1d)))
    logfile.write('Number of Azobenzene matches: {:>8d}\n'.format(len(matches_1a)))
    
    smiles_D, smiles_A=[],[]
    for molecule in matches_1d:
        smiles=Chem.MolToSmiles(molecule)
        smiles_D.append(smiles)
    for molecule in matches_1a:
        smiles=Chem.MolToSmiles(molecule)
        smiles_A.append(smiles)
    all_DataFrame_D=all_DataFrame_D+smiles_D
    all_DataFrame_A=all_DataFrame_A+smiles_A
    all_id_D = id_final1 + all_id_D
    all_id_A = id_final2 + all_id_A
    end = time.time()
    print('Finished, run time: {:>10.3f}s'.format(end - start))
all_id_D = pd.DataFrame(all_id_D)
all_id_A = pd.DataFrame(all_id_A)
all_DataFrame_A=pd.DataFrame(all_DataFrame_A)
all_DataFrame_D=pd.DataFrame(all_DataFrame_D)

Final_D = pd.concat([all_DataFrame_D,all_id_D],axis = 1)
Final_A = pd.concat([all_DataFrame_A,all_id_A],axis = 1)
Final_A.to_csv('MolPort_A_batch_7.csv')
Final_D.to_csv('MolPort_D_batch_7.csv')
logfile.close()
# Out:
# Batch no. 0  Finished, run time:     20.221s
# Batch no. 1  Finished, run time:     23.214s
# Batch no. 2  Finished, run time:     25.672s
# Batch no. 3  Finished, run time:     24.873s
# Batch no. 4  Finished, run time:     27.381s
# Batch no. 5  Finished, run time:     25.760s
# Batch no. 6  Finished, run time:     27.206s
# Batch no. 7  Finished, run time:     25.548s
# Batch no. 8  Finished, run time:     28.094s
# Batch no. 9  Finished, run time:     31.482s
# Batch no. 10  Finished, run time:     32.561s
# Batch no. 11  Finished, run time:     28.706s
# Batch no. 12  Finished, run time:     30.434s
# Batch no. 13  Finished, run time:     28.790s
# Batch no. 14  Finished, run time:     29.739s
# Batch no. 15  Finished, run time:     27.670s
# Batch no. 16  Finished, run time:     29.639s
# Batch no. 17  Finished, run time:     28.043s
# Batch no. 18  Finished, run time:     29.666s
# Batch no. 19  Finished, run time:     30.161s
# Batch no. 20  Finished, run time:     30.423s
# Batch no. 21  Finished, run time:     30.120s
# Batch no. 22  Finished, run time:     30.887s
# Batch no. 23  Finished, run time:     30.119s
# Batch no. 24  Finished, run time:     30.439s
# Batch no. 25  Finished, run time:     29.076s
# Batch no. 26  Finished, run time:     28.305s
# Batch no. 27  Finished, run time:     28.087s
# Batch no. 28  Finished, run time:     26.822s
# Batch no. 29  Finished, run time:     26.595s
# Batch no. 30  Finished, run time:     26.885s
# Batch no. 31  Finished, run time:     28.480s
# Batch no. 32  Finished, run time:     28.802s
# Batch no. 33  Finished, run time:     28.695s
# Batch no. 34  Finished, run time:     28.603s
# Batch no. 35  Finished, run time:     30.229s
# Batch no. 36  Finished, run time:     29.729s
# Batch no. 37  Finished, run time:     32.783s
# Batch no. 38  Finished, run time:     31.204s
# Batch no. 39  Finished, run time:     31.038s
# Batch no. 40  Finished, run time:     31.170s
# Batch no. 41  Finished, run time:     31.751s
# Batch no. 42  Finished, run time:     32.479s
# Batch no. 43  Finished, run time:     32.091s
# Batch no. 44  Finished, run time:     30.767s
# Batch no. 45  Finished, run time:     29.693s
# Batch no. 46  Finished, run time:     40.283s
# Batch no. 47  Finished, run time:     47.534s
# Batch no. 48  Finished, run time:     49.827s
# Batch no. 49  Finished, run time:     48.585s
# Batch no. 50  Finished, run time:      9.194s

# %%
data_full8 = pd.read_csv('fulldb8.txt', sep="	", header=0)
print(len(data_full8))
samplenum=len(data_full8)//samplesize+1
# Out:
# 5000003

# %%
all_DataFrame_A=[]
all_DataFrame_D=[]
all_id_D = []
all_id_A = []
logfile=open('logfile.txt','w')
for i in range(samplenum):
    if i==samplenum-1:
        data_segment_1=data_full8.loc[samplesize*i:]
    else:
        data_segment_1 = data_full8.loc[samplesize*i:samplesize*(i+1)]
    start = time.time()
    
    print('Batch no. {:d}'.format(i), end="  ")

    suppl = data_segment_1['SMILES'].tolist()
    supp2 = data_segment_1['MOLPORTID'].tolist()
    ms = []
    for smi in suppl:
        try: 
            ms.append(Chem.MolFromSmiles(smi))
        except:
            ms.append(None)
    ms_filter = list(filter(None, ms)) 
    id_filter = list(filter(None, supp2))
    indices1 = []
    indices2 = []
    matches_1d = []
    matches_1a = []
    
    for i,mol in enumerate(ms_filter):
        if mol.HasSubstructMatch(patt1):
            matches_1d.append(mol)
            indices1.append(i)
        if mol.HasSubstructMatch(patt2):
            matches_1a.append(mol)
            indices2.append(i)
    id_final1 = []
    id_final2 = []
    for i in indices1:
        id_final1.append(id_filter[i])
    for i in indices2:
        id_final2.append(id_filter[i])

    
    logfile.write('Batch number {:>20d}\n'.format(i))
    logfile.write('Number of Diarylethene matches: {:>8d}\n'.format(len(matches_1d)))
    logfile.write('Number of Azobenzene matches: {:>8d}\n'.format(len(matches_1a)))
    
    smiles_D, smiles_A=[],[]
    for molecule in matches_1d:
        smiles=Chem.MolToSmiles(molecule)
        smiles_D.append(smiles)
    for molecule in matches_1a:
        smiles=Chem.MolToSmiles(molecule)
        smiles_A.append(smiles)
    all_DataFrame_D=all_DataFrame_D+smiles_D
    all_DataFrame_A=all_DataFrame_A+smiles_A
    all_id_D = id_final1 + all_id_D
    all_id_A = id_final2 + all_id_A
    end = time.time()
    print('Finished, run time: {:>10.3f}s'.format(end - start))
all_id_D = pd.DataFrame(all_id_D)
all_id_A = pd.DataFrame(all_id_A)
all_DataFrame_A=pd.DataFrame(all_DataFrame_A)
all_DataFrame_D=pd.DataFrame(all_DataFrame_D)

Final_D = pd.concat([all_DataFrame_D,all_id_D],axis = 1)
Final_A = pd.concat([all_DataFrame_A,all_id_A],axis = 1)
Final_A.to_csv('MolPort_A_batch_8.csv')
Final_D.to_csv('MolPort_D_batch_8.csv')
logfile.close()
# Out:
# Batch no. 0  Finished, run time:     30.049s
# Batch no. 1  Finished, run time:     35.141s
# Batch no. 2  Finished, run time:     26.365s
# Batch no. 3  Finished, run time:     25.997s
# Batch no. 4  Finished, run time:     27.395s
# Batch no. 5  Finished, run time:     25.465s
# Batch no. 6  Finished, run time:     40.140s
# Batch no. 7  Finished, run time:     49.591s
# Batch no. 8  Finished, run time:     71.789s
# Batch no. 9  Finished, run time:     59.332s
# Batch no. 10  Finished, run time:     48.501s
# Batch no. 11  Finished, run time:     49.632s
# Batch no. 12  Finished, run time:     48.630s
# Batch no. 13  Finished, run time:     49.738s
# Batch no. 14  Finished, run time:     48.641s
# Batch no. 15  Finished, run time:     42.747s
# Batch no. 16  Finished, run time:     42.158s
# Batch no. 17  Finished, run time:     43.896s
# Batch no. 18  Finished, run time:     40.294s
# Batch no. 19  Finished, run time:     31.058s
# Batch no. 20  Finished, run time:     31.788s
# Batch no. 21  Finished, run time:     28.805s
# Batch no. 22  Finished, run time:     25.375s
# Batch no. 23  Finished, run time:     26.548s
# Batch no. 24  Finished, run time:     29.094s
# Batch no. 25  Finished, run time:     27.308s
# Batch no. 26  Finished, run time:     34.333s
# Batch no. 27  Finished, run time:     30.528s
# Batch no. 28  Finished, run time:     29.362s
# Batch no. 29  Finished, run time:     30.366s
# Batch no. 30  Finished, run time:     30.092s
# Batch no. 31  Finished, run time:     33.911s
# Batch no. 32  Finished, run time:     42.038s
# Batch no. 33  Finished, run time:     48.224s
# Batch no. 34  Finished, run time:     49.719s
# Batch no. 35  Finished, run time:     50.937s
# Batch no. 36  Finished, run time:     49.625s
# Batch no. 37  Finished, run time:     51.325s
# Batch no. 38  Finished, run time:     55.641s
# Batch no. 39  Finished, run time:     51.318s
# Batch no. 40  Finished, run time:     51.656s
# Batch no. 41  Finished, run time:     51.333s
# Batch no. 42  Finished, run time:     52.547s
# Batch no. 43  Finished, run time:     51.161s
# Batch no. 44  Finished, run time:     51.282s
# Batch no. 45  Finished, run time:     50.323s
# Batch no. 46  Finished, run time:     50.220s
# Batch no. 47  Finished, run time:     51.557s
# Batch no. 48  Finished, run time:     51.755s
# Batch no. 49  Finished, run time:     49.713s
# Batch no. 50  Finished, run time:      9.955s

# %%
data_full9 = pd.read_csv('fulldb9.txt', sep="	", header=0)
print(len(data_full9))
samplesize = 100000
samplenum=len(data_full9)//samplesize+1
# Out:
# 4999925

# %%
all_DataFrame_A=[]
all_DataFrame_D=[]
all_id_D = []
all_id_A = []
logfile=open('logfile.txt','w')
for i in range(samplenum):
    if i==samplenum-1:
        data_segment_1=data_full9.loc[samplesize*i:]
    else:
        data_segment_1 = data_full9.loc[samplesize*i:samplesize*(i+1)]
    start = time.time()
    
    print('Batch no. {:d}'.format(i), end="  ")

    suppl = data_segment_1['SMILES'].tolist()
    supp2 = data_segment_1['MOLPORTID'].tolist()
    ms = []
    for smi in suppl:
        try: 
            ms.append(Chem.MolFromSmiles(smi))
        except:
            ms.append(None)
    ms_filter = list(filter(None, ms)) 
    id_filter = list(filter(None, supp2))
    indices1 = []
    indices2 = []
    matches_1d = []
    matches_1a = []
    
    for i,mol in enumerate(ms_filter):
        if mol.HasSubstructMatch(patt1):
            matches_1d.append(mol)
            indices1.append(i)
        if mol.HasSubstructMatch(patt2):
            matches_1a.append(mol)
            indices2.append(i)
    id_final1 = []
    id_final2 = []
    for i in indices1:
        id_final1.append(id_filter[i])
    for i in indices2:
        id_final2.append(id_filter[i])

    
    logfile.write('Batch number {:>20d}\n'.format(i))
    logfile.write('Number of Diarylethene matches: {:>8d}\n'.format(len(matches_1d)))
    logfile.write('Number of Azobenzene matches: {:>8d}\n'.format(len(matches_1a)))
    
    smiles_D, smiles_A=[],[]
    for molecule in matches_1d:
        smiles=Chem.MolToSmiles(molecule)
        smiles_D.append(smiles)
    for molecule in matches_1a:
        smiles=Chem.MolToSmiles(molecule)
        smiles_A.append(smiles)
    all_DataFrame_D=all_DataFrame_D+smiles_D
    all_DataFrame_A=all_DataFrame_A+smiles_A
    all_id_D = id_final1 + all_id_D
    all_id_A = id_final2 + all_id_A
    end = time.time()
    print('Finished, run time: {:>10.3f}s'.format(end - start))
all_id_D = pd.DataFrame(all_id_D)
all_id_A = pd.DataFrame(all_id_A)
all_DataFrame_A=pd.DataFrame(all_DataFrame_A)
all_DataFrame_D=pd.DataFrame(all_DataFrame_D)

Final_D = pd.concat([all_DataFrame_D,all_id_D],axis = 1)
Final_A = pd.concat([all_DataFrame_A,all_id_A],axis = 1)
Final_A.to_csv('MolPort_A_batch_9.csv')
Final_D.to_csv('MolPort_D_batch_9.csv')
logfile.close()
# Out:
# Batch no. 0  Finished, run time:     33.408s
# Batch no. 1  Finished, run time:     23.515s
# Batch no. 2  Finished, run time:     26.652s
# Batch no. 3  Finished, run time:     33.341s
# Batch no. 4  Finished, run time:     40.455s
# Batch no. 5  Finished, run time:     43.837s
# Batch no. 6  Finished, run time:     44.395s
# Batch no. 7  Finished, run time:     38.332s
# Batch no. 8  Finished, run time:     38.122s
# Batch no. 9  Finished, run time:     37.864s
# Batch no. 10  Finished, run time:     45.618s
# Batch no. 11  Finished, run time:     44.543s
# Batch no. 12  Finished, run time:     39.399s
# Batch no. 13  Finished, run time:     39.952s
# Batch no. 14  Finished, run time:     43.523s
# Batch no. 15  Finished, run time:     40.567s
# Batch no. 16  Finished, run time:     41.717s
# Batch no. 17  Finished, run time:     39.793s
# Batch no. 18  Finished, run time:     43.432s
# Batch no. 19  Finished, run time:     38.062s
# Batch no. 20  Finished, run time:     35.820s
# Batch no. 21  Finished, run time:     35.748s
# Batch no. 22  Finished, run time:     57.488s
# Batch no. 23  Finished, run time:     79.645s
# Batch no. 24  Finished, run time:     72.769s
# Batch no. 25  Finished, run time:     52.860s
# Batch no. 26  Finished, run time:     49.755s
# Batch no. 27  Finished, run time:     47.053s
# Batch no. 28  Finished, run time:     47.679s
# Batch no. 29  Finished, run time:     61.637s
# Batch no. 30  Finished, run time:     65.731s
# Batch no. 31  Finished, run time:     55.402s
# Batch no. 32  Finished, run time:     55.118s
# Batch no. 33  Finished, run time:     52.278s
# Batch no. 34  Finished, run time:     46.226s
# Batch no. 35  Finished, run time:     52.045s
# Batch no. 36  Finished, run time:     52.309s
# Batch no. 37  Finished, run time:     48.491s
# Batch no. 38  Finished, run time:     42.006s
# Batch no. 39  Finished, run time:     40.864s
# Batch no. 40  Finished, run time:     35.590s
# Batch no. 41  Finished, run time:     46.445s
# Batch no. 42  Finished, run time:     53.518s
# Batch no. 43  Finished, run time:     47.058s
# Batch no. 44  Finished, run time:     42.200s
# Batch no. 45  Finished, run time:     43.518s
# Batch no. 46  Finished, run time:     43.001s
# Batch no. 47  Finished, run time:     43.021s
# Batch no. 48  Finished, run time:     44.553s
# Batch no. 49  Finished, run time:     47.460s

# %%
data_full10 = pd.read_csv('fulldb10.txt', sep="	", header=0)
print(len(data_full10))
samplenum=len(data_full10)//samplesize+1
# Out:
# 2196566

# %%
all_DataFrame_A=[]
all_DataFrame_D=[]
all_id_D = []
all_id_A = []
logfile=open('logfile.txt','w')
for i in range(samplenum):
    if i==samplenum-1:
        data_segment_1=data_full10.loc[samplesize*i:]
    else:
        data_segment_1 = data_full10.loc[samplesize*i:samplesize*(i+1)]
    start = time.time()
    
    print('Batch no. {:d}'.format(i), end="  ")

    suppl = data_segment_1['SMILES'].tolist()
    supp2 = data_segment_1['MOLPORTID'].tolist()
    ms = []
    for smi in suppl:
        try: 
            ms.append(Chem.MolFromSmiles(smi))
        except:
            ms.append(None)
    ms_filter = list(filter(None, ms)) 
    id_filter = list(filter(None, supp2))
    indices1 = []
    indices2 = []
    matches_1d = []
    matches_1a = []
    
    for i,mol in enumerate(ms_filter):
        if mol.HasSubstructMatch(patt1):
            matches_1d.append(mol)
            indices1.append(i)
        if mol.HasSubstructMatch(patt2):
            matches_1a.append(mol)
            indices2.append(i)
    id_final1 = []
    id_final2 = []
    for i in indices1:
        id_final1.append(id_filter[i])
    for i in indices2:
        id_final2.append(id_filter[i])

    
    logfile.write('Batch number {:>20d}\n'.format(i))
    logfile.write('Number of Diarylethene matches: {:>8d}\n'.format(len(matches_1d)))
    logfile.write('Number of Azobenzene matches: {:>8d}\n'.format(len(matches_1a)))
    
    smiles_D, smiles_A=[],[]
    for molecule in matches_1d:
        smiles=Chem.MolToSmiles(molecule)
        smiles_D.append(smiles)
    for molecule in matches_1a:
        smiles=Chem.MolToSmiles(molecule)
        smiles_A.append(smiles)
    all_DataFrame_D=all_DataFrame_D+smiles_D
    all_DataFrame_A=all_DataFrame_A+smiles_A
    all_id_D = id_final1 + all_id_D
    all_id_A = id_final2 + all_id_A
    end = time.time()
    print('Finished, run time: {:>10.3f}s'.format(end - start))
all_id_D = pd.DataFrame(all_id_D)
all_id_A = pd.DataFrame(all_id_A)
all_DataFrame_A=pd.DataFrame(all_DataFrame_A)
all_DataFrame_D=pd.DataFrame(all_DataFrame_D)

Final_D = pd.concat([all_DataFrame_D,all_id_D],axis = 1)
Final_A = pd.concat([all_DataFrame_A,all_id_A],axis = 1)
Final_A.to_csv('MolPort_A_batch_10.csv')
Final_D.to_csv('MolPort_D_batch_10.csv')
logfile.close()
# Out:
# Batch no. 0  Finished, run time:     57.901s
# Batch no. 1  Finished, run time:     56.886s
# Batch no. 2  Finished, run time:     46.226s
# Batch no. 3  Finished, run time:     48.042s
# Batch no. 4  Finished, run time:     34.627s
# Batch no. 5  Finished, run time:     27.470s
# Batch no. 6  Finished, run time:     35.143s
# Batch no. 7  Finished, run time:     44.860s
# Batch no. 8  Finished, run time:     51.603s
# Batch no. 9  Finished, run time:     55.929s
# Batch no. 10  Finished, run time:     55.035s
# Batch no. 11  Finished, run time:     53.379s
# Batch no. 12  Finished, run time:     65.453s
# Batch no. 13  Finished, run time:     71.998s
# Batch no. 14  Finished, run time:     66.664s
# Batch no. 15  Finished, run time:     57.682s
# Batch no. 16  Finished, run time:     49.120s
# Batch no. 17  Finished, run time:     54.983s
# Batch no. 18  Finished, run time:     55.183s
# Batch no. 19  Finished, run time:     58.971s
# Batch no. 20  Finished, run time:     53.234s
# Batch no. 21  Finished, run time:     49.017s

# %%
A1 = pd.read_csv("MolPort_A_batch_1.csv",sep=',',header = 0)
A1_smi = A1.iloc[:,1].tolist()
A1_id = A1.iloc[:,2].tolist()
A2 = pd.read_csv("MolPort_A_batch_2.csv",sep=',',header = 0)
A2_smi = A2.iloc[:,1].tolist()
A2_id = A2.iloc[:,2].tolist()
A3 = pd.read_csv("MolPort_A_batch_3.csv",sep=',',header = 0)
A3_smi = A3.iloc[:,1].tolist()
A3_id = A3.iloc[:,2].tolist()
A4 = pd.read_csv("MolPort_A_batch_4.csv",sep=',',header = 0)
A4_smi = A4.iloc[:,1].tolist()
A4_id = A4.iloc[:,2].tolist()
A5 = pd.read_csv("MolPort_A_batch_5.csv",sep=',',header = 0)
A5_smi = A5.iloc[:,1].tolist()
A5_id = A5.iloc[:,2].tolist()
A6 = pd.read_csv("MolPort_A_batch_6.csv",sep=',',header = 0)
A6_smi = A6.iloc[:,1].tolist()
A6_id = A6.iloc[:,2].tolist()
A7 = pd.read_csv("MolPort_A_batch_7.csv",sep=',',header = 0)
A7_smi = A7.iloc[:,1].tolist()
A7_id = A7.iloc[:,2].tolist()
A8 = pd.read_csv("MolPort_A_batch_8.csv",sep=',',header = 0)
A8_smi = A8.iloc[:,1].tolist()
A8_id = A8.iloc[:,2].tolist()
A9 = pd.read_csv("MolPort_A_batch_9.csv",sep=',',header = 0)
A9_smi = A9.iloc[:,1].tolist()
A9_id = A9.iloc[:,2].tolist()
A10 = pd.read_csv("MolPort_A_batch_10.csv",sep=',',header = 0)
A10_smi = A10.iloc[:,1].tolist()
A10_id = A10.iloc[:,2].tolist()

# %%
All_A_smi = A1_smi+A2_smi+A3_smi+A4_smi+A5_smi+A6_smi+A7_smi+A8_smi+A9_smi+A10_smi
All_A_id = A1_id+A2_id+A3_id+A4_id+A5_id+A6_id+A7_id+A8_id+A9_id+A10_id
All_A_smi_frame = pd.DataFrame(All_A_smi)
All_A_id_frame = pd.DataFrame(All_A_id)
Final_A = pd.concat([All_A_smi_frame,All_A_id_frame],axis = 1)
Final_A.to_csv('Final_Azobenzenes.csv')#Combine the filter results

# %%
A1 = pd.read_csv("MolPort_D_batch_1.csv",sep=',',header = 0)
A1_smi = A1.iloc[:,1].tolist()
A1_id = A1.iloc[:,2].tolist()
A2 = pd.read_csv("MolPort_D_batch_2.csv",sep=',',header = 0)
A2_smi = A2.iloc[:,1].tolist()
A2_id = A2.iloc[:,2].tolist()
A3 = pd.read_csv("MolPort_D_batch_3.csv",sep=',',header = 0)
A3_smi = A3.iloc[:,1].tolist()
A3_id = A3.iloc[:,2].tolist()
A4 = pd.read_csv("MolPort_D_batch_4.csv",sep=',',header = 0)
A4_smi = A4.iloc[:,1].tolist()
A4_id = A4.iloc[:,2].tolist()
A5 = pd.read_csv("MolPort_D_batch_5.csv",sep=',',header = 0)
A5_smi = A5.iloc[:,1].tolist()
A5_id = A5.iloc[:,2].tolist()
A6 = pd.read_csv("MolPort_D_batch_6.csv",sep=',',header = 0)
A6_smi = A6.iloc[:,1].tolist()
A6_id = A6.iloc[:,2].tolist()
A7 = pd.read_csv("MolPort_D_batch_7.csv",sep=',',header = 0)
A7_smi = A7.iloc[:,1].tolist()
A7_id = A7.iloc[:,2].tolist()
A8 = pd.read_csv("MolPort_D_batch_8.csv",sep=',',header = 0)
A8_smi = A8.iloc[:,1].tolist()
A8_id = A8.iloc[:,2].tolist()
A9 = pd.read_csv("MolPort_D_batch_9.csv",sep=',',header = 0)
A9_smi = A9.iloc[:,1].tolist()
A9_id = A9.iloc[:,2].tolist()
A10 = pd.read_csv("MolPort_D_batch_10.csv",sep=',',header = 0)
A10_smi = A10.iloc[:,1].tolist()
A10_id = A10.iloc[:,2].tolist()

# %%
All_A_smi = A1_smi+A2_smi+A3_smi+A4_smi+A5_smi+A6_smi+A7_smi+A8_smi+A9_smi+A10_smi
All_A_id = A1_id+A2_id+A3_id+A4_id+A5_id+A6_id+A7_id+A8_id+A9_id+A10_id
All_A_smi_frame = pd.DataFrame(All_A_smi)
All_A_id_frame = pd.DataFrame(All_A_id)
Final_A = pd.concat([All_A_smi_frame,All_A_id_frame],axis = 1)
Final_A.to_csv('Final_Diarylethenes.csv')

# %%
emol = pd.read_csv("eMol_All_A_batch.csv",sep=',',header = 0)

# %%
#Drop duplicates
import pandas as pd
A_df = pd.read_csv("eMol_D_batch.csv", sep=',', header=0) 
Azobenzenes_list = A_df.iloc[:,1].tolist()
Final_Azobenzenes_list = list(set(Azobenzenes_list))
#Final_Azobenzenes = pd.DataFrame(Final_Azobenzenes_list)
#Final_Azobenzenes.to_csv('Final_Azobenzenes.csv')

# %%
len(Azobenzenes_list)
# Out:
# 80197

# %%
len(Final_Azobenzenes_list)
# Out:
# 80188

# %%
#Add id
idlist = A_df.iloc[:,2].tolist()
indices_a=[]
ID=[]
for i,item in enumerate(Final_Azobenzenes_list):
    if item in Azobenzenes_list:
        indices_a.append(i)
        
for i in indices_a:
    ID.append(idlist[i])

# %%
len(ID)
# Out:
# 80188

# %%
Azo_MP1 = pd.DataFrame(ID,columns=['eMolecules ID'])
Azo_MP2 = pd.DataFrame(Final_Azobenzenes_list,columns=['Cannonical Smiles'])
Azo_MP = pd.concat([Azo_MP1, Azo_MP2], axis=1)
Azo_MP.to_csv('DIAR_EM.csv')

# %%
D_df = pd.read_csv("All_D_batch.csv", sep=',', header=0) 
Diarylethenes_list = D_df.iloc[:,2].tolist()
Final_Diarylethenes_list = list(set(Diarylethenes_list))
Final_Diarylethenes = pd.DataFrame(Final_Diarylethenes_list)
Final_Diarylethenes.to_csv('Final_Diarylethenes.csv')

# %%
allsmilesmolport = pd.read_csv("All_A_batch.csv", sep=',', header=0)
allsmilesemolecules = pd.read_csv("All_D_batch.csv", sep=',', header=0)

# %%
data1=pd.read_csv('fulldb1.txt', sep="	", header=0)
data2=pd.read_csv('fulldb2.txt', sep="	", header=0)
data3=pd.read_csv('fulldb3.txt', sep="	", header=0)
data4=pd.read_csv('fulldb4.txt', sep="	", header=0)
data5=pd.read_csv('fulldb5.txt', sep="	", header=0)
data6=pd.read_csv('fulldb6.txt', sep="	", header=0)
data7=pd.read_csv('fulldb7.txt', sep="	", header=0)
data8=pd.read_csv('fulldb8.txt', sep="	", header=0)
data9=pd.read_csv('fulldb9.txt', sep="	", header=0)
data10=pd.read_csv('fulldb10.txt', sep="	", header=0)

data_full_eMolecules = pd.read_csv('version.smi.txt', sep=" ", header=0)

# %%
allsmilesmolport_list = allsmilesmolport.iloc[:,1].tolist()
ID1=data1['MOLPORTID'].tolist()
ID2=data2['MOLPORTID'].tolist()
ID3=data3['MOLPORTID'].tolist()
ID4=data4['MOLPORTID'].tolist()
ID5=data5['MOLPORTID'].tolist()
ID6=data6['MOLPORTID'].tolist()
ID7=data7['MOLPORTID'].tolist()
ID8=data8['MOLPORTID'].tolist()
ID9=data9['MOLPORTID'].tolist()
ID10=data10['MOLPORTID'].tolist()
allIDmolport = ID1+ID2+ID3+ID4+ID5+ID6+ID7+ID8+ID9+ID10

allsmilesemolecules_list = allsmilesemolecules.iloc[:,1].tolist()
allIDemolecules = data_full_eMolecules['parent_id'].tolist()
